# %% [markdown]
# # What is Data Type
#
# **In Python, a data type is a classification that tells the interpreter what kind of value a variable holds and what specific operations can be performed on it. Because everything in Python is treated as an object, data types are actually classes, and variables are instances (objects) of those classes. Python is a dynamically typed language, meaning you do not need to explicitly declare the data type when creating a variable; the system infers it automatically based on the assigned value.**
#
# | Category | Data Types                         |
# | -------- | ---------------------------------- |
# | Numeric  | `int`, `float`, `complex`          |
# | Boolean  | `bool`                             |
# | Text     | `str`                              |
# | Sequence | `list`, `tuple`, `range`           |
# | Mapping  | `dict`                             |
# | Set      | `set`, `frozenset`                 |
# | Binary   | `bytes`, `bytearray`, `memoryview` |
# | Null     | `NoneType`                         |

# %% [markdown]
# 1. Integer

# %%
x = 10
y = -50
z = 100000000
print(x,y,z)
# Out:
# 10 -50 100000000

# %% [markdown]
# 2. Float

# %%
a=10.455
print(a)
# Out:
# 10.455

# %% [markdown]
# 3. Complex Number

# %%
x=2+3j
print("real :",x.real)
print("imaginary :",x.imag)
# Out:
# real : 2.0
# imaginary : 3.0

# %% [markdown]
# 4. Boolean

# %%
x=True
print(x)
# Out:
# True

# %%
True==1
False==0
# Out:
# True

# %% [markdown]
# False value include

# %%
False
None
0
0.0
''
[]
()
{}
set()
# Out:
# set()

# %% [markdown]
# 5. String

# %%
name = "Abhinay"
print(name)
# Out:
# Abhinay

# %% [markdown]
# Python string are unicode

# %%
"Hello"
"こんにちは"
"नमस्ते"
"😀"
# Out:
# '😀'

# %% [markdown]
# 6. NoneType

# %%
x=None
print(x)
# Out:
# None

# %% [markdown]
# 7. Bytes

# %%
x=b"hello"
print(x)
# Out:
# b'hello'

# %% [markdown]
# 8. Bytearray

# %%
x[0]
# Out:
# 104

# %%
x[-1]
# Out:
# 111

# %% [markdown]
# 9. Memoryview

# %%
data = bytearray(b"abcdef")

view = memoryview(data)
print(view)

# %%
print(bool)
# Out:
# <class 'bool'>

# %%
print(0 is False)
# Out:
# False
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\abhin\AppData\Local\Temp\ipykernel_31756\3158284529.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(0 is False)

# %%
x=None
print(x==None)
print(x is None)
# Out:
# True
# True
